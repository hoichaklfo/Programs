# %% [markdown]
# Car Evaluation
#
#
# The model evaluates cars according to the following concept structure:
# CAR car acceptability
# PRICE overall price
# buying buying price
# maint price of the maintenance
# TECH technical characteristics
# COMFORT comfort
# doors number of doors
# persons capacity in terms of persons to carry
# lug_boot the size of luggage boot
# safety estimated safety of the car
#
#
# Class Values:
# unacc, acc, good, vgood
#
#
# Attributes:
# buying: vhigh, high, med, low.
# maint: vhigh, high, med, low.
# doors: 2, 3, 4, 5more.
# persons: 2, 4, more.
# lug_boot: small, med, big.
# safety: low, med, high.

# %%
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv("car.data") # Load data as Pandas data structure

# %%
le = preprocessing.LabelEncoder() # A Pandas object to encode a list of data to 

buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

print(buying)
# Out:
# [3 3 3 ... 1 1 1]

# %%
# Getting features from each column and put them in tuples accordingly.

x = list(zip(buying, maint, door, persons, lug_boot, safety))  # features
y = list(cls)  # labels
print(x[0])
print(y[0])
# Out:
# (3, 3, 0, 0, 2, 1)
# 2

# %%
# Spliting the data into train and test set with the ratio of 9:1 
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.1)

# %%
#Training
model = KNeighborsClassifier(n_neighbors=9) # Setting hyperparameter K to an odd number is can better to avoid 'equal vote' 
model.fit(x_train, y_train) # Train
acc = model.score(x_test, y_test)
print('accuracy:', acc)
# Out:
# accuracy: 0.9364161849710982

# %%
classes = ["unacc", "acc", "good", "vgood"]

prediction = model.predict(x_test)

for i in range(len(prediction)):
    print('Data:', x_test[i])
    print('Actual class:', classes[y_test[i]])
    print('Prediction:', classes[prediction[i]])
    print('\n')
# Out:
# Data: (1, 0, 3, 0, 1, 1)
# Actual class: good
# Prediction: good
#
#
# Data: (2, 1, 0, 2, 1, 2)
# Actual class: unacc
# Prediction: good
#
#
# Data: (2, 0, 1, 1, 1, 2)
# Actual class: good
# Prediction: good
#
#
# Data: (1, 0, 0, 1, 0, 0)
# Actual class: vgood
# Prediction: unacc
#
#
# Data: (0, 2, 3, 0, 1, 2)
# Actual class: good
# Prediction: good
#
#
# Data: (3, 1, 2, 0, 1, 1)
# Actual class: good
# Prediction: good
#
#
# Data: (0, 3, 2, 1, 2, 0)
# Actual class: good
# Prediction: good
#
#
# Data: (1, 1, 1, 1, 1, 2)
# Actual class: unacc
# Prediction: unacc
#
#
# Data: (0, 2, 0, 2, 1, 0)
# Actual class: unacc
# Prediction: good
#
#
# Data: (2, 2, 1, 1, 0, 0)
# Actual class: vgood
# Prediction: vgood
#
#
# Data: (1, 2, 3, 2, 1, 2)
# Actual class: acc
# Prediction: unacc
#
#
# Data: (0, 3, 1, 1, 2, 0)
# Actual class: good
# Prediction: good
#
#
# Data: (0, 1, 0, 0, 2, 1)
# Actual class: good
# Prediction: good
#
#
# Data: (2, 3, 2, 0, 2, 0)
# Actual class: good
# Prediction: good
#
# ...
